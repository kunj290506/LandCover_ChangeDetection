# %% [markdown]
# # 🛰️ Land Cover Change Detection - Cloud Training
#
# This notebook allows you to easily train the Change Detection model on Google Colab's free GPU.
#
# ### Features:
# - **Automatic Setup**: Clones the repository and installs dependencies.
# - **Auto-Download**: Automatically downloads the latest model checkpoint after every epoch so you don't lose progress.
# - **Visual Progress**: Shows training loss and validation metrics in real-time.

# %%
# 1. Clone the Repository
# !git clone https://github.com/kunj290506/LandCover_ChangeDetection.git
# %cd LandCover_ChangeDetection
# !git pull origin main

# %%
# 2. Install Dependencies
# !pip install -r requirements.txt

# %%
# 3. Verify GPU Availability
import torch
if torch.cuda.is_available():
    print(f"✅ GPU Detected: {torch.cuda.get_device_name(0)}")
else:
    print("⚠️ No GPU detected. Please go to Runtime > Change runtime type > T4 GPU")

# %%
# 4. Start Training (Auto-Downloads Enabled)
# This will automatically trigger a browser download for 'latest_model.pth' after every epoch.
# !python src/train.py --data_root ./data/LEVIR-CD-patches --epochs 50 --batch_size 16
